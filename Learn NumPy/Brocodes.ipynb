# %% [markdown]
# ## NumPy Learning

# %%
import numpy as np

my_list  = [1,2,3,4]
my_list = my_list*2

print(my_list)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %% [markdown]
# Making NP Arrays

# %%
array = np.array(
                 [["a","b","c"],["x","y","z"]],
                 [["1","2","3"],["6","7","8"]]
                 )
